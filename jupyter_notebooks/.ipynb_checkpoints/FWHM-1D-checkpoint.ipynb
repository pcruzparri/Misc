# %%
import numpy as np
from scipy.optimize import curve_fit, root
import WrightTools as wt
import matplotlib.pyplot as plt
from scipy import signal as s
from scipy.stats import norm
from scipy.special import erfc, erf
from scipy.signal import find_peaks, peak_widths
import math


def gauss_curve(x, x0, a, sigma):
    return a * np.exp(-(x-x0)**2/(2*sigma**2))

def skew2(x, sigmag, mu, alpha, c, a):
    normpdf = (1 / (sigmag * np.sqrt(2 * math.pi))) * np.exp(-(np.power((x - mu), 2) / (2 * np.power(sigmag, 2))))
    normcdf = (0.5 * (1 + erf((alpha * ((x - mu) / sigmag)) / (np.sqrt(2)))))
    return 2 * a * normpdf * normcdf + c, np.max(normpdf)

def skew(x, mu, a, sigmag, alpha, c):
    return skew2(x, sigmag, mu, alpha, c, a)[0]

# %%
def skew3(x, sigmag, mu, alpha, a):
    normpdf = (1 / (sigmag * np.sqrt(2 * math.pi))) * np.exp(-(np.power((x - mu), 2) / (2 * np.power(sigmag, 2))))
    normcdf = (0.5 * (1 + erf((alpha * ((x - mu) / sigmag)) / (np.sqrt(2)))))
    return 2 * a * normpdf * normcdf

x = np.linspace(0,10,10000)
y1 = skew3(x, 1.5, 5, 0, 1)
y2 = 
plt.plot(x, y)

# %%
fn1 = 'C:\\Users\\Wright\\Downloads\\Broadband Sample Output Waldo\\2023-06-05 47793 grid_scan_wp mono rdc broadband resonant scan off delays dd3163af'+'\\primary.wt5'
data1 = wt.open(fn1)
data1.print_tree()
wt.artists.quick1D(data1, 'mono')
# Out:
# primary (C:\Users\Wright\AppData\Local\Temp\3wop9p10.wt5)
# ├── axes
# │   └── 0: mono (wn) (121,)
# ├── constants
# ├── variables
# │   ├── 0: labtime (s) (121,)
# │   ├── 1: hp (nm) (121,)
# │   ├── 2: hp_destination (nm) (121,)
# │   ├── 3: hp_Delay_1 (mm) (121,)
# │   ├── 4: hp_Delay_1_destination (mm) (121,)
# │   ├── 5: hp_Crystal_1 (deg) (121,)
# │   ├── 6: hp_Crystal_1_destination (deg) (121,)
# │   ├── 7: hp_Delay_2 (deg) (121,)
# │   ├── 8: hp_Delay_2_destination (deg) (121,)
# │   ├── 9: hp_Crystal_2 (deg) (121,)
# │   ├── 10: hp_Crystal_2_destination (deg) (121,)
# │   ├── 11: hp_SHG_Crystal (deg) (121,)
# │   ├── 12: hp_SHG_Crystal_destination (deg) (121,)
# │   ├── 13: hp_RP5_Stage (mm) (121,)
# │   ├── 14: hp_RP5_Stage_destination (mm) (121,)
# │   ├── 15: hp_WS_Wheel_1 (deg) (121,)
# │   ├── 16: hp_WS_Wheel_1_destination (deg) (121,)
# │   ├── 17: hp_RP6_Stage (deg) (121,)
# │   ├── 18: hp_RP6_Stage_destination (deg) (121,)
# │   ├── 19: hp_Crystal_Stage_2 (deg) (121,)
# │   ├── 20: hp_Crystal_Stage_2_destination (deg) (121,)
# │   ├── 21: hp_WS_Wheel_2 (deg) (121,)
# │   ├── 22: hp_WS_Wheel_2_destination (deg) (121,)
# │   ├── 23: hp_FH_IDL (deg) (121,)
# │   ├── 24: hp_FH_IDL_destination (deg) (121,)
# │   ├── 25: hp_d1 (ps) (121,)
# │   ├── 26: hp_d1_destination (ps) (121,)
# │   ├── 27: hp_d1_offset (ps) (121,)
# │   ├── 28: hp_d1_stage (mm) (121,)
# │   ├── 29: hp_d1_stage_destination (mm) (121,)
# │   ├── 30: hp_d2 (ps) (121,)
# │   ├── 31: hp_d2_destination (ps) (121,)
# │   ├── 32: hp_d2_offset (ps) (121,)
# │   ├── 33: hp_d2_stage (mm) (121,)
# │   ├── 34: hp_d2_stage_destination (mm) (121,)
# │   ├── 35: mono (nm) (121,)
# │   ├── 36: mono_destination (nm) (121,)
# │   ├── 37: twin2 (nm) (121,)
# │   ├── 38: twin2_destination (nm) (121,)
# │   ├── 39: twin2_Delay_1 (mm) (121,)
# │   ├── 40: twin2_Delay_1_destination (mm) (121,)
# │   ├── 41: twin2_Crystal_1 (deg) (121,)
# │   ├── 42: twin2_Crystal_1_destination (deg) (121,)
# │   ├── 43: twin2_Delay_2 (mm) (121,)
# │   ├── 44: twin2_Delay_2_destination (mm) (121,)
# │   ├── 45: twin2_Crystal_2 (deg) (121,)
# │   ├── 46: twin2_Crystal_2_destination (deg) (121,)
# │   ├── 47: twin2_SHG_Crystal (deg) (121,)
# │   ├── 48: twin2_SHG_Crystal_destination (deg) (121,)
# │   ├── 49: twin2_RP_Stage (mm) (121,)
# │   ├── 50: twin2_RP_Stage_destination (mm) (121,)
# │   ├── 51: twin2_DFG_CS_1 (deg) (121,)
# │   ├── 52: twin2_DFG_CS_1_destination (deg) (121,)
# │   ├── 53: twin2_d2 (ps) (121,)
# │   ├── 54: twin2_d2_destination (ps) (121,)
# │   ├── 55: twin2_d2_offset (ps) (121,)
# │   ├── 56: twin2_d2_stage (mm) (121,)
# │   ├── 57: twin2_d2_stage_destination (mm) (121,)
# │   ├── 58: d1 (ps) (121,)
# │   ├── 59: d1_destination (ps) (121,)
# │   ├── 60: d1_offset (ps) (121,)
# │   ├── 61: d1_stage (mm) (121,)
# │   ├── 62: d1_stage_destination (mm) (121,)
# │   ├── 63: d2 (ps) (121,)
# │   ├── 64: d2_destination (ps) (121,)
# │   ├── 65: d2_offset (ps) (121,)
# │   ├── 66: d2_stage (mm) (121,)
# │   ├── 67: d2_stage_destination (mm) (121,)
# │   ├── 68: twin1 (nm) (121,)
# │   ├── 69: twin1_destination (nm) (121,)
# │   ├── 70: twin1_Delay_1 (mm) (121,)
# │   ├── 71: twin1_Delay_1_destination (mm) (121,)
# │   ├── 72: twin1_Crystal_1 (deg) (121,)
# │   ├── 73: twin1_Crystal_1_destination (deg) (121,)
# │   ├── 74: twin1_Delay_2 (mm) (121,)
# │   ├── 75: twin1_Delay_2_destination (mm) (121,)
# │   ├── 76: twin1_Crystal_2 (deg) (121,)
# │   ├── 77: twin1_Crystal_2_destination (deg) (121,)
# │   ├── 78: twin1_RP_Stage (mm) (121,)
# │   ├── 79: twin1_RP_Stage_destination (mm) (121,)
# │   ├── 80: twin1_DFG_CS_1 (deg) (121,)
# │   ├── 81: twin1_DFG_CS_1_destination (deg) (121,)
# │   ├── 82: twin1_d1 (ps) (121,)
# │   ├── 83: twin1_d1_destination (ps) (121,)
# │   ├── 84: twin1_d1_offset (ps) (121,)
# │   ├── 85: twin1_d1_stage (mm) (121,)
# │   ├── 86: twin1_d1_stage_destination (mm) (121,)
# │   └── 87: mono_points (wn) (121,)
# └── channels
#     ├── 0: daq_ai0 (121,)
#     ├── 1: daq_ai1 (121,)
#     ├── 2: daq_ai2 (121,)
#     ├── 3: daq_ai3 (121,)
#     ├── 4: daq_ai0_a (121,)
#     ├── 5: daq_ai0_b (121,)
#     ├── 6: daq_ai0_c (121,)
#     ├── 7: daq_ai0_d (121,)
#     ├── 8: daq_ai0_diff_abcd (121,)
#     ├── 9: daq_ai0_diff_ab (121,)
#     └── 10: daq_ai0_diff_ad (121,)
# []

# %%
x1 = data1.axes[0].points
#print(x1)
y1 = data1.channels[8].points
mean = np.average(x1, weights=y1)
sigma = np.sqrt(sum(y1 * (x1 - mean)**2) / sum(y1))
test_amp = 2*max(y1)
print(mean, sigma, test_amp)
plt.plot(x1, y1)
# Out:
# 19933.548898273435 71.49364747446292 0.028039562671215504

# %%
fit1 = curve_fit(gauss_curve, x1, y1, p0=(mean, test_amp, sigma))
plt.plot(x1, y1)
plt.plot(x1, [gauss_curve(i, *fit1[0]) for i in x1])

# %%
fit2 = curve_fit(skew, x1, y1, p0=(mean, test_amp, sigma, -0.1, 0.0001))
print(fit2[0])
plt.plot(x1, y1)
plt.plot(x1, [skew(i,*fit2[0]) for i in x1])
# Out:
# [ 2.00128639e+04  1.48624555e+00  1.04989810e+02 -3.73871593e+00
#   1.29898684e-04]

# %%
peak, _ = find_peaks([skew(i,*fit2[0]) for i in x1])
width, _, left, right = peak_widths([skew(i,*fit2[0]) for i in x1], peak, rel_height=0.5)
plt.plot(x1, y1)
plt.plot(x1[int(peak)], [skew(i,*fit2[0]) for i in x1][int(peak)], 'k.')
plt.plot(x1[int(left)], [skew(i,*fit2[0]) for i in x1][int(left)], 'k.')
plt.plot(x1[int(right)], [skew(i,*fit2[0]) for i in x1][int(right)], 'k.')
plt.plot(x1, [skew(i,*fit2[0]) for i in x1])
plt.plot(x1[int(left):int(right)], [0.00506341 for i in x1[int(left):int(right)]])
print(width, _, left, right, (right-left)/len(x1)*(max(x1)-min(x1)))
# Out:
# [27.95362648] [0.00506341] [56.51350355] [84.46713003] [138.51918577]

# %%
width, right-left
# Out:
# (array([27.95362648]), array([27.95362648]))
