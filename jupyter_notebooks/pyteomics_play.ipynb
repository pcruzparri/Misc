# %%
from pyteomics import parser, mass, mzml, auxiliary
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Testing file reading and structure

# %%
fpath = r"C:\Users\student\Desktop\120426_Jurkat_highLC_Frac5.mzml"
with mzml.read(fpath) as reader:
    s = next(reader)
    auxiliary.print_tree(s)
    print('\n')
    print(s)
# Out:
# index
# id
# defaultArrayLength
# scanList
#  -> count
#  -> scan [list]
#  ->  -> scanWindowList
#  ->  ->  -> count
#  ->  ->  -> scanWindow [list]
#  ->  ->  ->  -> scan window lower limit
#  ->  ->  ->  -> scan window upper limit
#  ->  -> scan start time
#  ->  -> mass resolving power
#  ->  -> filter string
#  ->  -> preset scan configuration
#  ->  -> ion injection time
#  -> no combination
# MS1 spectrum
# ms level
# positive scan
# centroid spectrum
# base peak m/z
# base peak intensity
# total ion current
# lowest observed m/z
# highest observed m/z
# spectrum title
# count
# m/z array
# intensity array
#
#
# {'index': 0, 'id': 'controllerType=0 controllerNumber=1 scan=1', 'defaultArrayLength': 87, 'scanList': {'count': 1, 'scan': [{'scanWindowList': {'count': 1, 'scanWindow': [{'scan window lower limit': 300.0, 'scan window upper limit': 1500.0}]}, 'scan start time': 0.007588333333, 'mass resolving power': 60000.0, 'filter string': 'FTMS + c NSI Full ms [300.00-1500.00]', 'preset scan configuration': 1.0, 'ion injection time': 378.349365234375}], 'no combination': ''}, 'MS1 spectrum': '', 'ms level': 1, 'positive scan': '', 'centroid spectrum': '', 'base peak m/z': 1123.856567382813, 'base peak intensity': 225.084259033203, 'total ion current': 6178.63671875, 'lowest observed m/z': 303.06787109375, 'highest observed m/z': 1444.86083984375, 'spectrum title': '120426_Jurkat_highLC_Frac5.1.1. File:"120426_Jurkat_highLC_Frac5.raw", NativeID:"controllerType=0 controllerNumber=1 scan=1"', 'count': 2, 'm/z array': array([ 303.06787109,  303.99142456,  304.17602539,  304.36056519,
#         312.85333252,  316.79684448,  317.1539917 ,  325.15090942,
#         333.34536743,  345.94192505,  356.67599487,  357.88928223,
#         362.67559814,  365.20153809,  366.9755249 ,  375.12295532,
#         375.3807373 ,  375.9354248 ,  377.49252319,  393.83432007,
#         403.29846191,  407.64022827,  429.27191162,  464.47616577,
#         479.42514038,  499.49478149,  511.15048218,  522.25585938,
#         541.12792969,  568.31231689,  572.7010498 ,  596.1819458 ,
#         596.68927002,  605.94775391,  615.95172119,  624.55932617,
#         637.21136475,  637.77587891,  650.55841064,  662.5446167 ,
#         677.31390381,  697.84680176,  701.55310059,  709.66162109,
#         714.25488281,  719.23529053,  719.27215576,  729.94177246,
#         734.54095459,  735.19165039,  735.24133301,  735.94195557,
#         737.93292236,  738.75921631,  743.00238037,  799.20367432,
#         804.74041748,  812.08624268,  842.06878662,  887.85809326,
#         973.13262939,  981.21582031, 1039.09484863, 1055.19824219,
#        1071.45483398, 1093.72729492, 1117.49951172, 1119.48657227,
#        1123.85656738, 1126.06994629, 1141.02819824, 1148.78771973,
#        1148.81616211, 1148.84069824, 1150.19238281, 1184.71728516,
#        1205.45239258, 1220.65441895, 1232.76098633, 1253.56213379,
#        1311.00598145, 1370.34155273, 1374.98327637, 1380.74633789,
#        1382.00085449, 1390.0291748 , 1444.86083984]), 'intensity array': array([ 54.45346069,  76.38243866,  97.72433472,  74.56752014,
#         50.95722198,  62.6352272 ,  66.69676208,  59.74154282,
#         57.74266815,  53.66445923,  57.41734695,  53.76728439,
#         75.58087921,  56.56497574,  79.45733643,  54.40322495,
#         53.78798676,  63.71571732,  52.24298859,  58.20344543,
#         56.15746307,  53.81994629,  66.56282806,  52.08568192,
#         54.61190414, 126.61277008,  57.14474106,  58.30112076,
#         57.05434799,  56.62059402,  69.19191742, 188.78091431,
#         85.6035614 ,  66.81530762,  57.1007576 ,  68.70802307,
#         67.25132751,  56.85705185,  64.68050385,  55.6848259 ,
#        149.68360901,  60.13241959,  87.54553223,  66.99533081,
#         67.62402344,  69.40657043, 207.41061401,  68.67274475,
#         89.00165558,  70.83224487, 155.62971497,  68.2461319 ,
#         60.40404129, 104.04138184,  58.25948334,  55.48647308,
#         62.75391388,  55.87303162,  63.13570404,  55.60377884,
#         66.55673218,  55.00777817,  57.33026886,  56.80797195,
#         68.32158661,  52.15976334,  66.43200684,  55.45959854,
#        225.08425903,  54.71774292,  56.36058426,  64.41648102,
#         65.30173492,  55.67591858,  61.59988403,  67.92652893,
#         64.6631012 ,  70.39188385,  54.74324036,  60.5274086 ,
#         67.05921173,  68.05895233,  54.34527206,  62.82426834,
#         75.83892059,  55.01473999,  59.91982269])}

# %% [markdown]
# ## Draw Spectrum

# %%
d = mzml.PreIndexedMzML(fpath)

# %%
spect=d.next()
ymax = np.max(spect['intensity array'])
for i, x in enumerate(spect['m/z array']):
    plt.axvline(x=x, ymin=0, ymax=spect['intensity array'][i]/ymax)
plt.title(f'Scan Index={spect["index"]}.')
plt.xlabel('m/z')
plt.ylabel('intensity')
# Out:
# Text(0, 0.5, 'intensity')

# %% [markdown]
# ## Getting fake "diagnostic" m/z peaks

# %%
xs = []
ints = []
n_spects = 1000

for i, s in enumerate(d):
    if i<n_spects: 
        xs += list(s['m/z array'])
        ints += list(s['intensity array'])
    else: break

# %%
h = plt.hist(xs, bins=np.linspace(200, 1500, 50), weights=ints)
plt.ylabel('intensities')
plt.xlabel('binned m/z')
plt.title(f'weighed peak histogram of first {n_spects} spectra.')
# Out:
# Text(0.5, 1.0, 'weighed peak histogram of first 1000 spectra.')

# %%
np.argsort(h[0])[-2:]
# Out:
# array([ 8, 13], dtype=int64)

# %%
dp1 = np.sum(h[1][[8, 9]])/2
dp2 = np.sum(h[1][[13, 14]])/2
dp1, dp2
# Out:
# (425.51020408163265, 558.1632653061224)

# %% [markdown]
# Will use 425 and 558 as the fake diagnostic ions.

# %% [markdown]
# ## Find spectra with Diagnostic Ions

# %%
def nearest(arr, val):
    return np.argmin(np.abs(np.array(arr)-val))

# %%
tol = 20
sum_intensities = []
scan_idx = []
for spect in d: 
    mzs, ints = spect['m/z array'], spect['intensity array']
    idx1 = nearest(mzs, dp1)
    idx2 = nearest(mzs, dp2)
    if np.isclose(mzs[idx1], dp1, atol=tol) and np.isclose(mzs[idx2], dp2, atol=tol):
        sum_intensities+=[ints[idx1] + ints[idx2]]
        scan_idx+=[spect['index']] #arbitrary parameter chosen since no retention time.

# %%
max_int=max(sum_intensities)
for i, s in enumerate(scan_idx):
    plt.axvline(s, ymax=sum_intensities[i]/max_int)
