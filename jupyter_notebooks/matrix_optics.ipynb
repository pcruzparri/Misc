# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R
from mpl_toolkits.mplot3d import axes3d

# %%
x_rot = lambda theta: np.array([[1, 0, 0], 
                                [0, np.cos(theta), -np.sin(theta)], 
                                [0, np.sin(theta), np.cos(theta)]])
y_rot = lambda theta: np.array([[np.cos(theta), 0, np.sin(theta)],
                                [0, 1, 0], 
                                [-np.sin(theta), 0, np.cos(theta)]])
z_rot = lambda theta: np.array([[np.cos(theta), -np.sin(theta), 0], 
                                [np.sin(theta), np.cos(theta), 0],
                                [0, 0, 1]])

# %%
l1 = np.array([1, 0, 0])

l1_new = y_rot(np.deg2rad(45))@l1
l1_new
# Out:
# array([ 0.70710678,  0.        , -0.70710678])

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot(*[np.linspace(0, i) for i in l1])
ax.plot(*[np.linspace(0, i) for i in l1_new])
ax.legend()
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_zlim(-5,5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pyvista as pv
l1 = 1300
l2 = 1300
l3 = 1300
rot = R.from_quat([1,1,1,10])
rot.apply([1,0,0])
# Out:
# array([ 0.96116505,  0.21359223, -0.17475728])

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot(*np.array([1,0,0]).T, pointsize=10)
ax.plot(*np.array(rot.apply([1,0,0]).T), pointsize=10)
ax.legend()
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_zlim(-5,5)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 ax = plt.figure().add_subplot(projection='3d')
# ----> 2 ax.plot(*np.array([1,0,0]).T, pointsize=10)
#       3 ax.plot(*np.array(rot.apply([1,0,0]).T), pointsize=10)
#       4 ax.legend()
#
# File ~\Miniconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1497, in Axes3D.plot(self, xs, ys, zdir, *args, **kwargs)
#    1494 # Match length
#    1495 zs = np.broadcast_to(zs, np.shape(xs))
# -> 1497 lines = super().plot(xs, ys, *args, **kwargs)
#    1498 for line in lines:
#    1499     art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#
# File ~\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
# ...
