# %%
import nglview as nv
import rdkit

# %%
mol = rdkit.Chem.MolFromMolFile("C:\\Users\\student\\Downloads\\molecule.mol")
mol = rdkit.Chem.CleanupOrganometallics(mol)
view = nv.show_rdkit(mol)
# Out:
# [12:24:31] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[20], line 3
#       1 mol = rdkit.Chem.MolFromMolFile("C:\\Users\\student\\Downloads\\molecule.mol")
#       2 mol = rdkit.Chem.CleanupOrganometallics(mol)
# ----> 3 view = nv.show_rdkit(mol)
#
# File c:\Users\student\miniconda3\Lib\site-packages\nglview\show.py:373, in show_rdkit(rdkit_mol, **kwargs)
#     371 conf_id = kwargs.pop("conf_id", -1)
#     372 struc = RdkitStructure(rdkit_mol, ext=ext, conf_id=conf_id)
# --> 373 return NGLWidget(struc, **kwargs)
#
# File c:\Users\student\miniconda3\Lib\site-packages\nglview\widget.py:189, in NGLWidget.__init__(self, structure, representations, parameters, **kwargs)
#     187 self._initialize_attributes(kwargs)
#     188 self._initialize_threads()
# ...
