# %%
from koinapy import Koina

# %%
# All models
koina_models = [
    "AlphaPeptDeep_ms2_generic",
    "Altimeter_2024_intensities",
    "Altimeter_2024_isotopes",
    "Altimeter_2024_splines",
    "Altimeter_2024_splines_index",
    "Prosit_2019_intensity",
    "Prosit_2020_intensity_CID",
    "Prosit_2020_intensity_HCD",
    "Prosit_2020_intensity_TMT",
    "Prosit_2023_intensity_timsTOF",
    "Prosit_2024_intensity_PTMs_gl",
    "Prosit_2024_intensity_cit",
    "Prosit_2025_intensity_22PTM",
    "Prosit_2025_intensity_40PTM",
    "Prosit_2025_intensity_MultiFrag",
    "Prosit_2025_intensity_lac",
    "UniSpec",
    "ms2pip_CID_TMT",
    "ms2pip_HCD2021",
    "ms2pip_Immuno_HCD",
    "ms2pip_TTOF5600",
    "ms2pip_iTRAQphospho",
    "ms2pip_timsTOF2023",
    "ms2pip_timsTOF2024",
    "AlphaPeptDeep_rt_generic",
    "Chronologer_RT",
    "Deeplc_hela_hf",
    "Prosit_2019_irt",
    "Prosit_2020_irt_TMT",
    "Prosit_2024_irt_PTMs_gl",
    "Prosit_2024_irt_cit",
    "Prosit_2025_irt_22PTM",
    "Prosit_2025_irt_40PTM",
    "Prosit_2025_irt_lac",
    "AlphaPeptDeep_ccs_generic",
    "IM2Deep",
    "Prosit_2023_intensity_XL_CMS2",
    "Prosit_2023_intensity_XL_CMS3",
    "Prosit_2024_intensity_XL_NMS2",
    "3dmolms_orbitrap",
    "3dmolms_qtof",
    "pfly_2024_fine_tuned"
]

# %%
for model_name in koina_models:
    model = Koina(model_name)
    print(f"Model: {model_name}")
    print(f"Input features:", *list(model.model_inputs.keys()), sep="\n\t- ")
    print(f"Output features:", *list(model.model_outputs.keys()), sep="\n\t- ")
    print("-" * 40)
# Out:
# Model: AlphaPeptDeep_ms2_generic
# Input features:
# 	- peptide_sequences
# 	- precursor_charges
# 	- collision_energies
# 	- instrument_types
# Output features:
# 	- intensities
# 	- mz
# 	- annotation
# ----------------------------------------
# Model: Altimeter_2024_intensities
# Input features:
# 	- peptide_sequences
# 	- precursor_charges
# 	- collision_energies
# Output features:
# 	- intensities
# 	- annotations
# 	- mz
# ----------------------------------------
# Model: Altimeter_2024_isotopes
# Input features:
# 	- peptide_sequences
# 	- precursor_charges
# 	- collision_energies
# 	- isotope_isolation_efficiencies
# Output features:
# 	- intensities
# 	- annotations
# 	- mz
# ----------------------------------------
# Model: Altimeter_2024_splines
# Input features:
# 	- peptide_sequences
# 	- precursor_charges
# Output features:
# 	- coefficients
# 	- knots
# 	- annotations
# 	- mz
# ----------------------------------------
# Model: Altimeter_2024_splines_index
# ...
